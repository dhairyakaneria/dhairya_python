# %%
# Q.1 Welcome Message
print("Welcome to Python Programming")
# Out:
# Welcome to Python Programming

# %%
# Q.2 Address with escape characters
print("Rajesh Kumar Flat No. 101, Sunshine Apartments\nMG Road, Sector 15\nRajkot,\nPincode: 360004\n India. ")
# Out:
# Rajesh Kumar Flat No. 101, Sunshine Apartments
# MG Road, Sector 15
# Rajkot,
# Pincode: 360004
#  India.

# %%
# Q.3 Basic Mathematical Operations
num1 = 150
num2 = 120.50
print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
# Out:
# Addition: 270.5
# Subtraction: 29.5
# Multiplication: 18075.0
# Division: 1.2448132780082988

# %%
# Q.4 Area of Circle
radius = float(input("Enter the radius: "))
area = 3.14 * (radius ** 2)
circumference = 2 * 3.14 * radius
print(f"Area: {area}")
print(f"Circcumference: {circumference}")
# Out:
# Enter the radius:  12
# Area: 452.16
# Circcumference: 75.36

# %%
# Q.5 Simple Intrest 
P = float(input("Enter Principle amount: "))
R = float(input("Enter Rate of Intrest: "))
T = float(input("Enter Time (in years): "))
simple_intrest = (P * R * T) / 100
print(f"The Simple Intrest is: {simple_intrest}")
# Out:
# Enter Principle amount:  250000
# Enter Rate of Intrest:  5
# Enter Time (in years):  3
# The Simple Intrest is: 37500.0

# %%
# Q.6 Area and Perimeter of Rectangle
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width 
perimeter = 2 * (length + width)
print(f"Area: {area}, Perimeter: {perimeter}")
# Out:
# Enter length:  5
# Enter width:  8
# Area: 40.0, Perimeter: 26.0

# %%
# Q.7 Area and Perimeter of Square
side = float(input("Enter the side of the square: "))
area = side * side
perimeter = 4 * side
print(f"Area: {area}")
print(f"Perimeter: {perimeter}")
# Out:
# Enter the side of the square:  4
# Area: 16.0
# Perimeter: 16.0

# %%
# Q.8 Perimeter of triangle
side_a = float(input("Enter the length of side a: "))
side_b = float(input("Enter the length of side b: "))
side_c = float(input("Enter the length of side c: "))
perimeter = side_a + side_b + side_c
print("The perimeter of the triangle is:", perimeter)
# Out:
# Enter the length of side a:  5
# Enter the length of side b:  3
# Enter the length of side c:  4
# The perimeter of the triangle is: 12.0
